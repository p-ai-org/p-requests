# %% [markdown]
# # This is the notebook you can use to get the csv file containing all service requests between 2017 and 2019, along with their ElapsedTime and ElapsedDays.

# %%
import pandas as pd
import numpy as np 
from datetime import datetime
from datetime import date

# %%
#Adds ElaspedTime and ElapsedDays column. 


def convertTime(string):
    """Converts a string to a datetime object.
    """
    time = datetime.strptime(string,'%m/%d/%Y %I:%M:%S %p') 
    return time

def convertDays(string):
    """
    Converts string to date object. 
    """
    time = datetime.strptime(string[:10],'%m/%d/%Y') #Accepts time string, converts it to datetime object.
    return time

def convertFromSeconds(s): # total seconds
    """ convertFromSeconds(s): Converts an integer # of seconds into a list of [days, hours, minutes, seconds]
        input s: an int
    """
    s = s*60
    days = s // (24*60*60)  # total days
    s = s % (24*60*60) # remainder s
    hours = s // (60*60) # total hours
    s = s % (60*60) # remainder s
    minutes = s // 60 # total minutes
    s = s % 60 # remainder s
    statement = (days, ' days') + (hours, ' hrs') +(minutes, ' mins') + (s, 'sec')
    return statement
    
def elapsedTime(csv2017, csv2018, csv2019):
    """
    Accepts CSV files containing 2017-2019 service requests and creates new dataframe of all timestamps for both service request submission and fulfillment times.
    Input CSV file in the format: r'filepath'
    Data source: https://data.lacity.org/A-Well-Run-City/MyLA311-Service-Request-Data-2019/pvft-t768
    """
    df = pd.concat(map(pd.read_csv, [csv2017, csv2018, csv2019]), ignore_index = True)
    
    hdf = df.dropna(axis=0, subset=['CreatedDate', 'ClosedDate'])

    #ElapsedTime 
    df1 = hdf['ClosedDate'].apply(convertTime, 0)
    df2 = hdf['CreatedDate'].apply(convertTime, 0)
    
    hdf['ElapsedTime'] = df1 - df2  
    hdf['ElapsedTime'] = hdf['ElapsedTime']/np.timedelta64(1,'m') 
    hdf['ElapsedTime'] = hdf['ElapsedTime'].apply(convertFromSeconds, 0)   
    
    #ElapsedDays
    df3 = hdf['CreatedDate'].apply(convertDays, 0)
    df4 = hdf['ClosedDate'].apply(convertDays, 0) 
    hdf['ElapsedDays'] = (df4 - df3).dt.days
    
    #Column for Closed Dates
    hdf['Just Date'] = df3
    
    return hdf.reset_index(drop = True)


def elapsedTime2020(df):
    """
    Creates elapsedTime, elapsedDays, and date columns. 
    """
    #df = pd.read_csv(csv)
    
    hdf = df.dropna(axis=0, subset=['CreatedDate', 'ClosedDate'])

    #ElapsedTime 
    df1 = hdf['ClosedDate'].apply(convertTime, 0)   
    df2 = hdf['CreatedDate'].apply(convertTime, 0)
 
    hdf['ElapsedTime'] = df1 - df2
    hdf['ElapsedTime'] = hdf['ElapsedTime']/np.timedelta64(1,'m') 
    hdf['ElapsedTime'] = hdf['ElapsedTime'].apply(convertFromSeconds, 0)   
    
    #ElapsedDays
    df3 = hdf['CreatedDate'].apply(convertDays, 0)
    df4 = hdf['ClosedDate'].apply(convertDays, 0) 
    hdf['ElapsedDays'] = (df4 - df3).dt.days
    
    #Column for Closed Dates
    hdf['Just Date'] = df3
    
    return hdf.reset_index(drop = True).sort_index(axis=1)

def cleaned_df(csv): 
    """
    Take in 2020 dataset and return dataset with ElapsedTime, ElapsedDays, and date columns
    Data: https://data.lacity.org/A-Well-Run-City/MyLA311-Service-Request-Data-2020/rq3b-xjk8
    """
    df = pd.read_csv(csv) 
    df = df.drop(143589,axis=0).reset_index(drop = True)  #This row was mislabled (the year inputted was 3020, not 2020)
    edf = elapsedTime2020(df)
    edf = edf[edf.ElapsedDays >= 0]
    
    return edf

# %%
edf = elapsedTime('service2017.csv', 'service2018.csv', 'service2019.csv')
edf2 = cleaned_df('service2020.csv')
# Out:
# C:\Users\ngeta\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   """Entry point for launching an IPython kernel.
# C:\Users\ngeta\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:37: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
# C:\Users\ngeta\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ngeta\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ngeta\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ngeta\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ngeta\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ngeta\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3214: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):
# C:\Users\ngeta\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ngeta\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ngeta\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ngeta\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ngeta\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
edf = edf[edf['ElapsedDays'] < 1100]   #Some of the service requests had dates which were mislabelled, resulting in impossible ElapsedDay values. This command gets rid of those requests.

# %%
d = pd.read_csv('service2020.csv')
# Out:
# C:\Users\ngeta\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_final = pd.concat([edf,edf2])
# Out:
# C:\Users\ngeta\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
edf
# Out:
#                            APC ActionTaken  \
# 0         West Los Angeles APC  SR Created
# 1         East Los Angeles APC  SR Created
# 2         West Los Angeles APC  SR Created
# 3             North Valley APC  SR Created
# 4             North Valley APC  SR Created
# 5         East Los Angeles APC  SR Created
# 6                  Central APC  SR Created
# 7         East Los Angeles APC  SR Created
# 8             North Valley APC  SR Created
# 9                  Central APC  SR Created
# 10            North Valley APC  SR Created
# 11        East Los Angeles APC  SR Created
# 12        East Los Angeles APC  SR Created
# 13                 Central APC  SR Created
# 14            South Valley APC  SR Created
# 15                 Central APC  SR Created
# 16            South Valley APC  SR Created
# 17            South Valley APC  SR Created
# 18       South Los Angeles APC  SR Created
# 19            South Valley APC  SR Created
# 20            South Valley APC  SR Created
# 21            South Valley APC  SR Created
# 22            South Valley APC  SR Created
# 23        East Los Angeles APC  SR Created
# 24       South Los Angeles APC  SR Created
# 25        East Los Angeles APC  SR Created
# 26        West Los Angeles APC  SR Created
# 27       South Los Angeles APC  SR Created
# 28       South Los Angeles APC  SR Created
# 29            North Valley APC  SR Created
# ...                        ...         ...
# 3030802       North Valley APC  SR Created
# 3030803             Harbor APC  SR Created
# 3030804             Harbor APC  SR Created
# 3030805       North Valley APC  SR Created
# 3030806            Central APC  SR Created
# 3030807            Central APC  SR Created
# 3030808       South Valley APC  SR Created
# 3030809       North Valley APC  SR Created
# 3030810            Central APC  SR Created
# 3030811   East Los Angeles APC  SR Created
# 3030812            Central APC  SR Created
# 3030813       South Valley APC  SR Created
# 3030814            Central APC  SR Created
# 3030815       North Valley APC  SR Created
# 3030816            Central APC  SR Created
# 3030817   East Los Angeles APC  SR Created
# 3030818   East Los Angeles APC  SR Created
# 3030819   East Los Angeles APC  SR Created
# 3030820       South Valley APC  SR Created
# 3030821       South Valley APC  SR Created
# 3030822            Central APC  SR Created
# 3030823       South Valley APC  SR Created
# 3030824            Central APC  SR Created
# 3030825   East Los Angeles APC  SR Created
# 3030826   East Los Angeles APC  SR Created
# 3030827       North Valley APC  SR Created
# 3030828            Central APC  SR Created
# 3030829  South Los Angeles APC  SR Created
# 3030830       North Valley APC  SR Created
# 3030831                    NaN  SR Created
#
#                                     Address AddressVerified Anonymous  \
# 0                   222 N ASHDALE PL, 90049               Y         Y
# 1               1624 N ALLESANDRO ST, 90026               Y         Y
# 2                  250 N ASHDALE AVE, 90049               Y         Y
# 3              21824 W DEVONSHIRE ST, 91311               Y         N
# 4              21230 W DEVONSHIRE ST, 91311               Y         N
# 5                2630 E CARLETON AVE, 90065               Y         Y
# 6                    747 N SEWARD ST, 90038               Y         N
# 7                4850 N ELLENWOOD DR, 90041               Y         N
# 8        10236 N TOPANGA CANYON BLVD, 91311               Y         N
# 9             3814 W COUNTRY CLUB DR, 90019               Y         N
# 10             21812 W DEVONSHIRE ST, 91311               Y         N
# 11               4850 N ELLENWOOD DR, 90041               Y         N
# 12               4850 N ELLENWOOD DR, 90041               Y         N
# 13                   2281 N HOLLY DR, 90068               Y         N
# 14             5424 N SEPULVEDA BLVD, 91411               Y         N
# 15             1128 N LAS PALMAS AVE, 90038               Y         N
# 16            5000 N LANKERSHIM BLVD, 91601               Y         Y
# 17            4910 N LANKERSHIM BLVD, 91601               Y         Y
# 18                1547 W VENICE BLVD, 90006               Y         Y
# 19            4883 N LANKERSHIM BLVD, 91601               Y         Y
# 20               11023 W HARTSOOK ST, 91601               Y         N
# 21            4821 N LANKERSHIM BLVD, 91601               Y         Y
# 22                23034 W ENADIA WAY, 91307               Y         N
# 23        FIGUEROA ST AT BURWOOD AVE, 90042               Y         N
# 24            4700 W WASHINGTON BLVD, 90016               Y         Y
# 25              2322 N RIVERDALE AVE, 90031               Y         N
# 26               8131 S LINCOLN BLVD, 90045               Y         Y
# 27                   1464 E 106TH ST, 90002               Y         N
# 28                4161 S FIGUEROA ST, 90037               Y         Y
# 29                11844 W SATICOY ST, 91605               Y         Y
# ...                                     ...             ...       ...
# 3030802       10413 N OWENSMOUTH AVE, 91311               Y         N
# 3030803         20607 S HARVARD BLVD, 90501               Y         N
# 3030804         20607 S HARVARD BLVD, 90501               Y         N
# 3030805          13032 N PORTOLA WAY, 91342               Y         N
# 3030806              101 N CROFT AVE, 90048               Y         N
# 3030807           627 N ROSSMORE AVE, 90004               Y         N
# 3030808       5551 N LANKERSHIM BLVD, 91601               Y         N
# 3030809          20651 W ROSCOE BLVD, 91306               Y         N
# 3030810         1466 S SHERBOURNE DR, 90035               Y         N
# 3030811               2580 N SOTO ST, 90032               Y         N
# 3030812          1433 N CHEROKEE AVE, 90028               Y         N
# 3030813          7327 N IRONDALE AVE, 91306               Y         N
# 3030814    1420 W JAMES M. WOOD BLVD, 90015               Y         Y
# 3030815         8730 W FOOTHILL BLVD, 91040               Y         N
# 3030816           5525 W SUNSET BLVD, 90028               Y         N
# 3030817     4114 W SANTA MONICA BLVD, 90029               Y         Y
# 3030818               2019 N ALTA ST, 90031               Y         N
# 3030819            3906 N HAWLEY AVE, 90032               Y         N
# 3030820              18230 W LULL ST, 91335               Y         N
# 3030821   VANOWEN ST AT SHOSHONE AVE, 91406               Y         Y
# 3030822             4303 W PICO BLVD, 90019               Y         N
# 3030823           20403 W ARMINTA ST, 91306               Y         N
# 3030824             940 N WILCOX AVE, 90038               Y         N
# 3030825            4493 E PYRITES ST, 90032               Y         N
# 3030826            4493 E PYRITES ST, 90032               Y         N
# 3030827              14945 W TUBA ST, 91345               Y         N
# 3030828         5348 W LEXINGTON AVE, 90029               Y         N
# 3030829            1717 E VERNON AVE, 90058               Y         N
# 3030830      10049 N HAYVENHURST AVE, 91343               Y         N
# 3030831  1717 E VERNON AV{\n  error" : true               Y         N
#
#         ApproximateAddress  AssignTo    CD             CDMember  \
# 0                        N       NaN   5.0          Paul Koretz
# 1                        N      CCAC  13.0      Mitch O'Farrell
# 2                        N       NaN   5.0          Paul Koretz
# 3                        N       WVA  12.0   Mitchell Englander
# 4                        N       WVA  12.0   Mitchell Englander
# 5                        N  NEGB_ELA   1.0      Gilbert Cedillo
# 6                      NaN        NC   4.0            David Ryu
# 7                      NaN        NC  14.0          Jose Huizar
# 8                      NaN        WV  12.0   Mitchell Englander
# 9                      NaN        NC  10.0   Herb J. Wesson Jr.
# 10                       N       WVA  12.0   Mitchell Englander
# 11                     NaN        NC  14.0          Jose Huizar
# 12                     NaN        NC  14.0          Jose Huizar
# 13                       N       NaN   4.0            David Ryu
# 14                       N        EV   4.0            David Ryu
# 15                     NaN        NC   4.0            David Ryu
# 16                     NaN     NORTH   2.0       Paul Krekorian
# 17                     NaN     NORTH   2.0       Paul Krekorian
# 18                       N       SLA   1.0      Gilbert Cedillo
# 19                     NaN     NORTH   2.0       Paul Krekorian
# 20                       N        EV   2.0       Paul Krekorian
# 21                     NaN     NORTH   2.0       Paul Krekorian
# 22                       N        WV  12.0                  NaN
# 23                       N        NC  14.0          Jose Huizar
# 24                       N       NaN  10.0   Herb J. Wesson Jr.
# 25                       N        NC  13.0      Mitch O'Farrell
# 26                     NaN      WEST  11.0           Mike Bonin
# 27                       N        HB  15.0         Joe Buscaino
# 28                       N      CRCD   9.0  Curren D. Price Jr.
# 29                       N        EV   2.0       Paul Krekorian
# ...                    ...       ...   ...                  ...
# 3030802                NaN        WV  12.0          Greig Smith
# 3030803                  N        HB  15.0         Joe Buscaino
# 3030804                  N        HB  15.0         Joe Buscaino
# 3030805                  N        EV   7.0     Monica Rodriguez
# 3030806                NaN       WLA   5.0          Paul Koretz
# 3030807                  N        NC   4.0            David Ryu
# 3030808                NaN        EV   2.0       Paul Krekorian
# 3030809                NaN        WV   3.0      Bob Blumenfield
# 3030810                  N       WLA   5.0          Paul Koretz
# 3030811                  N        NC  14.0          Jose Huizar
# 3030812                NaN        NC  13.0      Mitch O'Farrell
# 3030813                NaN        WV   3.0      Bob Blumenfield
# 3030814                NaN   CENTRAL   1.0      Gilbert Cedillo
# 3030815                  N        EV   7.0     Monica Rodriguez
# 3030816                  N       HBT  13.0      Mitch O'Farrell
# 3030817                  N       HBT  13.0      Mitch O'Farrell
# 3030818                NaN        NC   1.0      Gilbert Cedillo
# 3030819                  N        NC  14.0          Jose Huizar
# 3030820                  N        WV  12.0          Greig Smith
# 3030821                  N       WVA   6.0        Nury Martinez
# 3030822                  N      KYCC  10.0   Herb J. Wesson Jr.
# 3030823                  N        WV   3.0      Bob Blumenfield
# 3030824                  N        NC  13.0      Mitch O'Farrell
# 3030825                  N        NC  14.0          Jose Huizar
# 3030826                  N        NC  14.0          Jose Huizar
# 3030827                NaN        EV   7.0     Monica Rodriguez
# 3030828                  N        NC  13.0      Mitch O'Farrell
# 3030829                  N      CRCD   9.0  Curren D. Price Jr.
# 3030830                  N       WVA  12.0          Greig Smith
# 3030831                  N      CRCD   NaN                  NaN
#
#                      ClosedDate  ...      StreetName Suffix TBMColumn  \
# 0        01/01/2017 09:26:00 AM  ...         ASHDALE     PL         H
# 1        01/12/2017 05:10:00 PM  ...      ALLESANDRO     ST         E
# 2        01/01/2017 09:27:00 AM  ...         ASHDALE    AVE         H
# 3        01/04/2017 05:33:00 PM  ...      DEVONSHIRE     ST         A
# 4        01/04/2017 05:34:00 PM  ...      DEVONSHIRE     ST         B
# 5        01/03/2017 06:55:00 PM  ...        CARLETON    AVE         H
# 6        01/07/2017 09:46:00 AM  ...          SEWARD     ST         E
# 7        01/04/2017 09:31:00 AM  ...       ELLENWOOD     DR         J
# 8        01/04/2017 09:51:00 AM  ...  TOPANGA CANYON   BLVD         A
# 9        01/07/2017 08:53:00 AM  ...    COUNTRY CLUB     DR         G
# 10       01/04/2017 05:36:00 PM  ...      DEVONSHIRE     ST         A
# 11       01/04/2017 09:32:00 AM  ...       ELLENWOOD     DR         J
# 12       01/04/2017 09:32:00 AM  ...       ELLENWOOD     DR         J
# 13       01/01/2017 09:36:00 AM  ...           HOLLY     DR         E
# 14       01/01/2017 10:56:00 AM  ...       SEPULVEDA   BLVD         H
# 15       01/07/2017 08:19:00 AM  ...      LAS PALMAS    AVE         E
# 16       01/05/2017 07:49:00 AM  ...      LANKERSHIM   BLVD         A
# 17       01/05/2017 07:49:00 AM  ...      LANKERSHIM   BLVD         A
# 18       01/01/2017 01:34:00 PM  ...          VENICE   BLVD         B
# 19       01/05/2017 07:49:00 AM  ...      LANKERSHIM   BLVD         A
# 20       01/04/2017 07:38:00 AM  ...        HARTSOOK     ST         A
# 21       01/05/2017 07:49:00 AM  ...      LANKERSHIM   BLVD         A
# 22       01/07/2017 08:03:00 AM  ...          ENADIA    NaN         G
# 23       01/01/2017 10:39:00 AM  ...             NaN    NaN         D
# 24       01/01/2017 09:20:00 AM  ...      WASHINGTON   BLVD         D
# 25       01/05/2017 11:12:00 AM  ...       RIVERDALE    AVE         H
# 26       01/03/2017 04:08:00 PM  ...         LINCOLN   BLVD         D
# 27       01/01/2017 11:24:00 AM  ...           106TH     ST         F
# 28       01/17/2017 12:31:00 PM  ...        FIGUEROA     ST         B
# 29       01/04/2017 01:36:00 PM  ...         SATICOY     ST         G
# ...                         ...  ...             ...    ...       ...
# 3030802  07/23/2019 09:40:00 AM  ...      OWENSMOUTH    AVE         A
# 3030803  07/22/2019 05:13:00 PM  ...         HARVARD   BLVD         J
# 3030804  07/22/2019 05:18:00 PM  ...         HARVARD   BLVD         J
# 3030805  07/22/2019 12:14:00 PM  ...         PORTOLA    WAY         E
# 3030806  07/25/2019 02:30:00 PM  ...           CROFT    AVE         A
# 3030807  07/26/2019 03:58:00 PM  ...        ROSSMORE    AVE         F
# 3030808  07/23/2019 02:58:00 PM  ...      LANKERSHIM   BLVD         J
# 3030809  07/23/2019 05:16:00 PM  ...          ROSCOE   BLVD         C
# 3030810  07/26/2019 07:50:00 AM  ...      SHERBOURNE     DR         J
# 3030811  07/22/2019 07:04:00 AM  ...            SOTO     ST         C
# 3030812  07/26/2019 12:28:00 PM  ...        CHEROKEE    AVE         E
# 3030813  07/23/2019 05:34:00 PM  ...        IRONDALE    AVE         C
# 3030814  08/15/2019 12:00:00 AM  ...   JAMES M. WOOD   BLVD         D
# 3030815  07/22/2019 01:06:00 PM  ...        FOOTHILL   BLVD         F
# 3030816  07/23/2019 03:13:00 PM  ...          SUNSET   BLVD         H
# 3030817  07/23/2019 12:02:00 PM  ...    SANTA MONICA   BLVD         B
# 3030818  07/22/2019 03:22:00 PM  ...            ALTA     ST         B
# 3030819  07/22/2019 09:31:00 AM  ...          HAWLEY    AVE         D
# 3030820  07/22/2019 04:14:00 PM  ...            LULL     ST         J
# 3030821  07/25/2019 05:28:00 PM  ...             NaN    NaN         B
# 3030822  07/23/2019 11:28:00 AM  ...            PICO   BLVD         F
# 3030823  07/23/2019 05:42:00 PM  ...         ARMINTA     ST         D
# 3030824  07/26/2019 03:50:00 PM  ...          WILCOX    AVE         F
# 3030825  07/22/2019 07:54:00 AM  ...         PYRITES     ST         D
# 3030826  07/22/2019 07:23:00 AM  ...         PYRITES     ST         D
# 3030827  07/26/2019 09:27:00 AM  ...            TUBA     ST         J
# 3030828  07/26/2019 04:52:00 PM  ...       LEXINGTON    AVE         H
# 3030829  08/16/2019 09:58:00 AM  ...          VERNON    AVE         G
# 3030830  07/22/2019 07:34:00 PM  ...     HAYVENHURST    AVE         D
# 3030831  08/14/2019 07:44:00 AM  ...             NaN    NaN       NaN
#
#          TBMPage  TBMRow             UpdatedDate  ZipCode  \
# 0          631.0     1.0  01/01/2017 09:26:00 AM    90049
# 1          594.0     6.0  01/12/2017 05:10:00 PM    90026
# 2          631.0     1.0  01/01/2017 09:27:00 AM    90049
# 3          500.0     4.0  01/04/2017 05:33:00 PM    91311
# 4          500.0     4.0  01/04/2017 05:34:00 PM    91311
# 5          594.0     5.0  01/03/2017 06:55:00 PM    90065
# 6          593.0     6.0  01/07/2017 09:46:00 AM    90038
# 7          564.0     6.0  01/04/2017 09:31:00 AM    90041
# 8          500.0     4.0  01/04/2017 09:51:00 AM    91311
# 9          633.0     4.0  01/07/2017 08:53:00 AM    90019
# 10         500.0     4.0  01/04/2017 05:36:00 PM    91311
# 11         564.0     6.0  01/04/2017 09:32:00 AM    90041
# 12         564.0     6.0  01/04/2017 09:32:00 AM    90041
# 13         593.0     3.0  01/01/2017 09:36:00 AM    90068
# 14         561.0     2.0  01/01/2017 10:56:00 AM    91411
# 15         593.0     5.0  01/07/2017 08:19:00 AM    90038
# 16         563.0     3.0  01/05/2017 07:49:00 AM    91601
# 17         563.0     3.0  01/05/2017 07:49:00 AM    91601
# 18         634.0     5.0  01/01/2017 01:34:00 PM    90006
# 19         563.0     3.0  01/05/2017 07:49:00 AM    91601
# 20         563.0     2.0  01/04/2017 07:38:00 AM    91601
# 21         563.0     3.0  01/05/2017 07:49:00 AM    91601
# 22         529.0     5.0  01/07/2017 08:03:00 AM    91307
# 23         565.0     7.0  01/01/2017 10:39:00 AM    90042
# 24         633.0     6.0  01/01/2017 09:20:00 AM    90016
# 25         594.0     5.0  01/05/2017 11:12:00 AM    90031
# 26         702.0     2.0  01/03/2017 04:08:00 PM    90045
# 27         704.0     5.0  01/01/2017 11:24:00 AM    90002
# 28         674.0     3.0  01/17/2017 12:31:00 PM    90037
# 29         532.0     3.0  01/04/2017 01:36:00 PM    91605
# ...          ...     ...                     ...      ...
# 3030802    500.0     4.0  07/24/2019 04:51:00 AM    91311
# 3030803    763.0     5.0  07/22/2019 05:13:00 PM    90501
# 3030804    763.0     5.0  07/22/2019 05:18:00 PM    90501
# 3030805    482.0     3.0  07/22/2019 12:57:00 PM    91342
# 3030806    633.0     1.0  07/25/2019 02:30:00 PM    90048
# 3030807    593.0     7.0  07/26/2019 03:58:00 PM    90004
# 3030808    562.0     1.0  07/23/2019 02:58:00 PM    91601
# 3030809    530.0     2.0  07/23/2019 05:16:00 PM    91306
# 3030810    632.0     4.0  07/26/2019 07:50:00 AM    90035
# 3030811    595.0     7.0  07/22/2019 07:04:00 AM    90032
# 3030812    593.0     5.0  07/26/2019 07:26:00 PM    90028
# 3030813    530.0     4.0  07/23/2019 05:34:00 PM    91306
# 3030814    634.0     4.0  08/16/2019 08:05:00 AM    90015
# 3030815    503.0     3.0  07/22/2019 01:09:00 PM    91040
# 3030816    593.0     4.0  07/23/2019 03:13:00 PM    90028
# 3030817    594.0     5.0  07/23/2019 12:02:00 PM    90029
# 3030818    635.0     1.0  07/22/2019 03:22:00 PM    90031
# 3030819    595.0     5.0  07/22/2019 09:57:00 AM    90032
# 3030820    530.0     4.0  07/22/2019 04:14:00 PM    91335
# 3030821    531.0     6.0  07/25/2019 05:28:00 PM    91406
# 3030822    633.0     4.0  07/23/2019 11:28:00 AM    90019
# 3030823    530.0     3.0  07/23/2019 05:42:00 PM    91306
# 3030824    593.0     6.0  07/26/2019 07:44:00 PM    90038
# 3030825    595.0     6.0  07/22/2019 07:54:00 AM    90032
# 3030826    595.0     6.0  07/22/2019 07:23:00 AM    90032
# 3030827    501.0     4.0  07/26/2019 09:31:00 AM    91345
# 3030828    593.0     5.0  07/26/2019 04:52:00 PM    90029
# 3030829    674.0     3.0  08/16/2019 09:58:00 AM    90058
# 3030830    501.0     4.0  07/22/2019 07:34:00 PM    91343
# 3030831      NaN     NaN  08/14/2019 07:44:00 AM      NaN
#
#                                               ElapsedTime  ElapsedDays  \
# 0          (0.0,  days, 9.0,  hrs, 25.0,  mins, 0.0, sec)            0
# 1        (11.0,  days, 16.0,  hrs, 25.0,  mins, 0.0, sec)           11
# 2          (0.0,  days, 8.0,  hrs, 41.0,  mins, 0.0, sec)            0
# 3         (3.0,  days, 16.0,  hrs, 32.0,  mins, 0.0, sec)            3
# 4         (3.0,  days, 16.0,  hrs, 25.0,  mins, 0.0, sec)            3
# 5         (2.0,  days, 17.0,  hrs, 39.0,  mins, 0.0, sec)            2
# 6          (6.0,  days, 8.0,  hrs, 25.0,  mins, 0.0, sec)            6
# 7           (3.0,  days, 8.0,  hrs, 5.0,  mins, 0.0, sec)            3
# 8          (3.0,  days, 8.0,  hrs, 20.0,  mins, 0.0, sec)            3
# 9           (6.0,  days, 7.0,  hrs, 6.0,  mins, 0.0, sec)            6
# 10        (3.0,  days, 15.0,  hrs, 41.0,  mins, 0.0, sec)            3
# 11         (3.0,  days, 7.0,  hrs, 32.0,  mins, 0.0, sec)            3
# 12         (3.0,  days, 7.0,  hrs, 28.0,  mins, 0.0, sec)            3
# 13         (0.0,  days, 7.0,  hrs, 21.0,  mins, 0.0, sec)            0
# 14         (0.0,  days, 8.0,  hrs, 36.0,  mins, 0.0, sec)            0
# 15         (6.0,  days, 5.0,  hrs, 47.0,  mins, 0.0, sec)            6
# 16         (4.0,  days, 5.0,  hrs, 11.0,  mins, 0.0, sec)            4
# 17         (4.0,  days, 5.0,  hrs, 10.0,  mins, 0.0, sec)            4
# 18        (0.0,  days, 10.0,  hrs, 54.0,  mins, 0.0, sec)            0
# 19          (4.0,  days, 5.0,  hrs, 8.0,  mins, 0.0, sec)            4
# 20         (3.0,  days, 4.0,  hrs, 57.0,  mins, 0.0, sec)            3
# 21          (4.0,  days, 5.0,  hrs, 6.0,  mins, 0.0, sec)            4
# 22         (6.0,  days, 4.0,  hrs, 40.0,  mins, 0.0, sec)            6
# 23         (0.0,  days, 6.0,  hrs, 49.0,  mins, 0.0, sec)            0
# 24         (0.0,  days, 4.0,  hrs, 38.0,  mins, 0.0, sec)            0
# 25         (4.0,  days, 6.0,  hrs, 29.0,  mins, 0.0, sec)            4
# 26        (2.0,  days, 11.0,  hrs, 13.0,  mins, 0.0, sec)            2
# 27         (0.0,  days, 5.0,  hrs, 53.0,  mins, 0.0, sec)            0
# 28         (16.0,  days, 6.0,  hrs, 3.0,  mins, 0.0, sec)           16
# 29         (3.0,  days, 6.0,  hrs, 42.0,  mins, 0.0, sec)            3
# ...                                                   ...          ...
# 3030802   (1.0,  days, 13.0,  hrs, 13.0,  mins, 0.0, sec)            2
# 3030803   (0.0,  days, 20.0,  hrs, 44.0,  mins, 0.0, sec)            1
# 3030804   (0.0,  days, 20.0,  hrs, 48.0,  mins, 0.0, sec)            1
# 3030805   (0.0,  days, 15.0,  hrs, 42.0,  mins, 0.0, sec)            1
# 3030806   (3.0,  days, 17.0,  hrs, 58.0,  mins, 0.0, sec)            4
# 3030807   (4.0,  days, 19.0,  hrs, 25.0,  mins, 0.0, sec)            5
# 3030808   (1.0,  days, 18.0,  hrs, 25.0,  mins, 0.0, sec)            2
# 3030809   (1.0,  days, 20.0,  hrs, 43.0,  mins, 0.0, sec)            2
# 3030810   (4.0,  days, 11.0,  hrs, 16.0,  mins, 0.0, sec)            5
# 3030811   (0.0,  days, 10.0,  hrs, 30.0,  mins, 0.0, sec)            1
# 3030812   (4.0,  days, 15.0,  hrs, 53.0,  mins, 0.0, sec)            5
# 3030813   (1.0,  days, 20.0,  hrs, 59.0,  mins, 0.0, sec)            2
# 3030814   (24.0,  days, 3.0,  hrs, 23.0,  mins, 0.0, sec)           25
# 3030815   (0.0,  days, 16.0,  hrs, 26.0,  mins, 0.0, sec)            1
# 3030816   (1.0,  days, 18.0,  hrs, 32.0,  mins, 0.0, sec)            2
# 3030817   (1.0,  days, 15.0,  hrs, 19.0,  mins, 0.0, sec)            2
# 3030818   (0.0,  days, 18.0,  hrs, 39.0,  mins, 0.0, sec)            1
# 3030819   (0.0,  days, 12.0,  hrs, 47.0,  mins, 0.0, sec)            1
# 3030820   (0.0,  days, 19.0,  hrs, 30.0,  mins, 0.0, sec)            1
# 3030821   (3.0,  days, 20.0,  hrs, 43.0,  mins, 0.0, sec)            4
# 3030822   (1.0,  days, 14.0,  hrs, 43.0,  mins, 0.0, sec)            2
# 3030823   (1.0,  days, 20.0,  hrs, 57.0,  mins, 0.0, sec)            2
# 3030824    (4.0,  days, 19.0,  hrs, 4.0,  mins, 0.0, sec)            5
# 3030825    (0.0,  days, 11.0,  hrs, 8.0,  mins, 0.0, sec)            1
# 3030826   (0.0,  days, 10.0,  hrs, 35.0,  mins, 0.0, sec)            1
# 3030827   (4.0,  days, 12.0,  hrs, 37.0,  mins, 0.0, sec)            5
# 3030828    (4.0,  days, 20.0,  hrs, 2.0,  mins, 0.0, sec)            5
# 3030829   (25.0,  days, 13.0,  hrs, 7.0,  mins, 0.0, sec)           26
# 3030830   (0.0,  days, 22.0,  hrs, 43.0,  mins, 0.0, sec)            1
# 3030831  (23.0,  days, 10.0,  hrs, 51.0,  mins, 0.0, sec)           24
#
#          Just Date
# 0       2017-01-01
# 1       2017-01-01
# 2       2017-01-01
# 3       2017-01-01
# 4       2017-01-01
# 5       2017-01-01
# 6       2017-01-01
# 7       2017-01-01
# 8       2017-01-01
# 9       2017-01-01
# 10      2017-01-01
# 11      2017-01-01
# 12      2017-01-01
# 13      2017-01-01
# 14      2017-01-01
# 15      2017-01-01
# 16      2017-01-01
# 17      2017-01-01
# 18      2017-01-01
# 19      2017-01-01
# 20      2017-01-01
# 21      2017-01-01
# 22      2017-01-01
# 23      2017-01-01
# 24      2017-01-01
# 25      2017-01-01
# 26      2017-01-01
# 27      2017-01-01
# 28      2017-01-01
# 29      2017-01-01
# ...            ...
# 3030802 2019-07-21
# 3030803 2019-07-21
# 3030804 2019-07-21
# 3030805 2019-07-21
# 3030806 2019-07-21
# 3030807 2019-07-21
# 3030808 2019-07-21
# 3030809 2019-07-21
# 3030810 2019-07-21
# 3030811 2019-07-21
# 3030812 2019-07-21
# 3030813 2019-07-21
# 3030814 2019-07-21
# 3030815 2019-07-21
# 3030816 2019-07-21
# 3030817 2019-07-21
# 3030818 2019-07-21
# 3030819 2019-07-21
# 3030820 2019-07-21
# 3030821 2019-07-21
# 3030822 2019-07-21
# 3030823 2019-07-21
# 3030824 2019-07-21
# 3030825 2019-07-21
# 3030826 2019-07-21
# 3030827 2019-07-21
# 3030828 2019-07-21
# 3030829 2019-07-21
# 3030830 2019-07-21
# 3030831 2019-07-21
#
# [3030813 rows x 37 columns]

# %%
df_final.tail()
# Out:
#                            APC ActionTaken                       Address  \
# 1061511       South Valley APC  SR Created   5755 N WILKINSON AVE, 91607
# 1061512  South Los Angeles APC  SR Created         1062 W 56TH ST, 90037
# 1061513       North Valley APC  SR Created  10435 N WHEATLAND AVE, 91040
# 1061514            Central APC  SR Created          3945 W 8TH ST, 90005
# 1061515                    NaN  SR Created     8801 N SNOWDEN AVE, 91331
#
#         AddressVerified Anonymous ApproximateAddress AssignTo   CD  \
# 1061511               Y         N                  N       EV  2.0
# 1061512               Y         N                  N      SLA  9.0
# 1061513               Y         N                NaN       EV  7.0
# 1061514               Y         N                  N       NC  4.0
# 1061515               Y         N                  N       EV  NaN
#
#                     CDMember              ClosedDate  ...      SRNumber  \
# 1061511       Paul Krekorian  09/29/2020 07:05:15 AM  ...  1-1749237311
# 1061512  Curren D. Price Jr.  09/23/2020 03:57:34 PM  ...  1-1749238151
# 1061513     Monica Rodriguez  09/28/2020 05:28:33 PM  ...  1-1749237341
# 1061514            David Ryu  09/25/2020 07:11:02 AM  ...  1-1749236441
# 1061515                  NaN  10/01/2020 07:52:14 AM  ...  1-1749236501
#
#                     ServiceDate  Status  StreetName Suffix  TBMColumn TBMPage  \
# 1061511  09/29/2020 12:00:00 AM  Closed   WILKINSON    AVE          F   562.0
# 1061512  09/23/2020 12:00:00 AM  Closed        56TH     ST          A   674.0
# 1061513  09/28/2020 12:00:00 AM  Closed   WHEATLAND    AVE          B   503.0
# 1061514  09/25/2020 12:00:00 AM  Closed         8TH     ST          H   633.0
# 1061515  10/01/2020 12:00:00 AM  Closed     SNOWDEN    AVE        NaN     NaN
#
#          TBMRow             UpdatedDate  ZipCode
# 1061511     1.0  09/29/2020 07:08:20 AM    91607
# 1061512     5.0  09/23/2020 03:58:49 PM    90037
# 1061513     3.0  09/28/2020 05:30:18 PM    91040
# 1061514     3.0  09/25/2020 07:17:30 AM    90005
# 1061515     NaN  10/02/2020 05:27:13 AM    91331
#
# [5 rows x 37 columns]

# %%
df_final.to_csv('2020service.csv',index=False)

# %%
edf.to_csv('fservice.csv', index = False)

# %%
df = pd.read_csv('fservice.csv')
# Out:
# C:\Users\ngeta\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (10,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#                     APC ActionTaken                       Address  \
# 0  West Los Angeles APC  SR Created       222 N ASHDALE PL, 90049
# 1  East Los Angeles APC  SR Created   1624 N ALLESANDRO ST, 90026
# 2  West Los Angeles APC  SR Created      250 N ASHDALE AVE, 90049
# 3      North Valley APC  SR Created  21824 W DEVONSHIRE ST, 91311
# 4      North Valley APC  SR Created  21230 W DEVONSHIRE ST, 91311
#
#   AddressVerified Anonymous ApproximateAddress AssignTo    CD  \
# 0               Y         Y                  N      NaN   5.0
# 1               Y         Y                  N     CCAC  13.0
# 2               Y         Y                  N      NaN   5.0
# 3               Y         N                  N      WVA  12.0
# 4               Y         N                  N      WVA  12.0
#
#              CDMember              ClosedDate  ...  StreetName Suffix  \
# 0         Paul Koretz  01/01/2017 09:26:00 AM  ...     ASHDALE     PL
# 1     Mitch O'Farrell  01/12/2017 05:10:00 PM  ...  ALLESANDRO     ST
# 2         Paul Koretz  01/01/2017 09:27:00 AM  ...     ASHDALE    AVE
# 3  Mitchell Englander  01/04/2017 05:33:00 PM  ...  DEVONSHIRE     ST
# 4  Mitchell Englander  01/04/2017 05:34:00 PM  ...  DEVONSHIRE     ST
#
#   TBMColumn  TBMPage  TBMRow             UpdatedDate  ZipCode  \
# 0         H    631.0     1.0  01/01/2017 09:26:00 AM    90049
# 1         E    594.0     6.0  01/12/2017 05:10:00 PM    90026
# 2         H    631.0     1.0  01/01/2017 09:27:00 AM    90049
# 3         A    500.0     4.0  01/04/2017 05:33:00 PM    91311
# 4         B    500.0     4.0  01/04/2017 05:34:00 PM    91311
#
#                                          ElapsedTime  ElapsedDays   Just Date
# 0  (0.0, ' days', 9.0, ' hrs', 25.0, ' mins', 0.0...            0  2017-01-01
# 1  (11.0, ' days', 16.0, ' hrs', 25.0, ' mins', 0...           11  2017-01-01
# 2  (0.0, ' days', 8.0, ' hrs', 41.0, ' mins', 0.0...            0  2017-01-01
# 3  (3.0, ' days', 16.0, ' hrs', 32.0, ' mins', 0....            3  2017-01-01
# 4  (3.0, ' days', 16.0, ' hrs', 25.0, ' mins', 0....            3  2017-01-01
#
# [5 rows x 37 columns]
