# %%
# Import libraries
import dataset2020 #Our custom code with the pipeline, elapsed time function, etc.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from datetime import datetime
import seaborn as sns
from scipy import stats

# %%
df = dataset2020.cleaned_df('/Users/antoniorevilla/Downloads/MyLA311_Service_Request_Data_2020.csv')

# %%
df['month'] = pd.DatetimeIndex(df['CreatedDate']).month # Create month column with value 1-12 representing CreatedDate month
df['month']
# Out:
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
#            ..
# 1222907    10
# 1222908    10
# 1222909    10
# 1222910    10
# 1222911    10
# Name: month, Length: 1222861, dtype: int64

# %%
df[(df['month'] >= 3) & (df['month'] <= 10)] # Limits dataset to months >= 3 (March) and months <= 10 (October)
df['month']
# Out:
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
#            ..
# 1222907    10
# 1222908    10
# 1222909    10
# 1222910    10
# 1222911    10
# Name: month, Length: 1222861, dtype: int64

# %%
num_bins = len(df['month'].unique()) # Set bin number to the # of months (i.e. the number of unique values in the month col )

# %%
# Matplotlib Historgram for 2020 Requests

# Set plot size
plt.figure(figsize=(12,7))

# Add title and axis names
plt.title('March-October 2020')
plt.xlabel('month')
plt.ylabel('# of requests')

# Limits for the X axis -- start to end month
plt.xlim(3,10) 

plt.hist(df['month'], bins=num_bins, edgecolor='black')
# Out:
# (array([124278., 101495., 104251., 108288., 127487., 134711., 136405.,
#         134311., 130074., 121561.]),
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  <BarContainer object of 10 artists>)

# %%
# Pandas Histogram for 2020 Requests

# Add title and axis names
plt.title('March-October 2020')
plt.xlabel('month')
plt.ylabel('# of requests')

# Set x limits -- start to end month
plt.xlim(3,10) 

hist = df['month'].hist(bins=num_bins, figsize=(12,7), edgecolor='Black')
