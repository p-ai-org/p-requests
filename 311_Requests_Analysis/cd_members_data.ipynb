# %%
import numpy as np
import pandas as pd
from datetime import datetime 
from datetime import timedelta
import csv 
import matplotlib.pyplot as plt
from datetime import date
from datetime import time
import seaborn as sns

# %%
def convertTimeStamp(string):
    """Converts a string to a datetime object.
    """
    time = datetime.strptime(string,'%m/%d/%Y %I:%M:%S %p') #Accepts time string, converts it to datetime object.
    return time

# %%
#convert seconds to weeks, days, hours, minutes, seconds

intervals = (
    ('weeks', 604800),  # 60 * 60 * 24 * 7
    ('days', 86400),    # 60 * 60 * 24
    ('hours', 3600),    # 60 * 60
    ('minutes', 60),
    ('seconds', 1),
    )

def display_time(seconds, granularity=2):
    result = []

    for name, count in intervals:
        value = seconds // count
        if value:
            seconds -= value * count
            if value == 1:
                name = name.rstrip('s')
            result.append("{} {}".format(value, name))
    return ', '.join(result[:granularity])

# %%
def councilTime(filepath):
    """councilTime accepts a csv file and returns a dataframe which displays the average elapsed time between created date 
        and update date for service requests in each distinct council member in 2018."""
    
    dataframe = pd.read_csv(filepath)
    
    #filter unique CDMember values from the dataset
    dataframe1 = dataframe['CDMember'].dropna().unique()
    
    #filter dateset to CreatedDate and ClosedDate columns
    created_df = dataframe['CreatedDate'].dropna().apply(convertTimeStamp, 0) #apply convertTimeStamp to CreatedDate
    Closed_df = dataframe['ClosedDate'].dropna().apply(convertTimeStamp, 0) #apply convertTimeStamp to ClosedDate
    elapsed_df = Closed_df - created_df #calculate the difference in the values in CreatedDate and ClosedDate
    dataframe3 = [created_df, Closed_df, elapsed_df] #combinedataframes created_df, Closed_df, elapsed_df into one dataframe
    
   

    #insert elapsed time column into dataset
    dataframe.insert(3, "ElapsedTime", elapsed_df) #create column ElapsedTime with dataframe elapsed_df into dataframe dataframe
    
    elapsed_seconds = dataframe['ElapsedTime'].dt.total_seconds()
    dataframe.insert(4, 'ElapsedTime in Seconds', elapsed_seconds)
    
    df4 = dataframe[['CDMember', 'ElapsedTime', 'ElapsedTime in Seconds']] #create a dataframe df4 with columns CDMember, ElapsedTime, Elapsed Time in Seconds from dataframe
    df4 = df4.sort_values('CDMember').dropna() #sort df4 by rows in column CDMember
    
    
    #create dataframes for each unique council member with ElapsedTime column
    for member in dataframe1:
        print('Elapsed Times by City Council Members', member)
        is_member =  df4['CDMember']==member
        df4_member = df4[is_member]
        
        member_col = df4_member[['ElapsedTime']]
        print(member_col)
        
        #find average elapsed time for each council member
        elapsed_avg = df4_member['ElapsedTime in Seconds'].mean()
        elapsed_avg = display_time(elapsed_avg, 5)

        print('\nAverage Elapsed Time for', member,':', elapsed_avg)
        print('\n\n')

# %%
councilTime(r"C:\Users\hanaa\Downloads\MyLA311_Service_Request_Data_2017.csv")
# Out:
# C:\Users\hanaa\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3249: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# 411644 1 days 14:16:00
# 804017 1 days 14:38:00
# 1732   1 days 23:06:00
# 34745  2 days 22:33:00
#
# [58109 rows x 1 columns]
#
# Average Elapsed Time for Bob Blumenfield : 3.0 days, 20.0 hours, 29.0 minutes, 18.0 seconds
#
#
#
# Elapsed Times by City Council Members Curren D. Price Jr.
#             ElapsedTime
# 295700  0 days 00:00:00
# 824091  4 days 23:42:00
# 295625  0 days 00:00:00
# 295702  0 days 00:00:00
# 924772  1 days 06:19:00
# ...                 ...
# 600868  0 days 23:58:00
# 1003027 0 days 00:00:00
# 599430  0 days 00:00:00
# 599429  0 days 00:00:00
# 597118  0 days 00:00:00
#
# [122880 rows x 1 columns]
#
# Average Elapsed Time for Curren D. Price Jr. : 4.0 days, 14.0 hours, 37.0 minutes, 23.0 seconds
#
#
#
# Elapsed Times by City Council Members Marqueece Harris-Dawson
#            ElapsedTime
# 880490 1 days 20:21:00
# 776121 0 days 04:32:00
# 775179 2 days 21:17:00
# 45397  0 days 15:36:00
# 880976 8 days 16:16:00
# ...                ...
# 473458 1 days 00:27:00
# 361669 1 days 04:44:00
# 788969 0 days 22:46:00
# 90399  5 days 22:01:00
# 894725 0 days 16:39:00
#
# [86250 rows x 1 columns]
#
# Average Elapsed Time for Marqueece Harris-Dawson : 3.0 days, 9.0 hours, 51.0 minutes, 37.0 seconds
#
#
#
# Elapsed Times by City Council Members David Ryu
#               ElapsedTime
# 786599    0 days 14:52:00
# 437782    0 days 00:15:00
# 228271    7 days 06:06:00
# 237317    2 days 20:12:00
# 806261    6 days 04:42:00
# ...                   ...
# 86724   -1 days +11:29:00
# 1013481   4 days 02:08:00
# 1004952   1 days 15:32:00
# 1130493   1 days 04:20:00
# 206839    5 days 16:32:00
#
# [56895 rows x 1 columns]
#
# Average Elapsed Time for David Ryu : 4.0 days, 22.0 hours, 23.0 minutes, 59.0 seconds
#
#
#
# Elapsed Times by City Council Members Vacant
#            ElapsedTime
# 951756 4 days 04:14:00
# 665416 5 days 20:35:00
# 866227 1 days 02:39:00
# 662476 5 days 01:13:00
# 764743 0 days 00:00:00
# ...                ...
# 843774 0 days 00:00:00
# 843773 0 days 00:00:00
# 843772 0 days 00:00:00
# 843784 0 days 00:00:00
# 772805 0 days 00:00:00
#
# [27952 rows x 1 columns]
#
# Average Elapsed Time for Vacant : 3.0 days, 23.0 hours, 1.0 minute, 16.0 seconds
#
#
#
# Elapsed Times by City Council Members Felipe Fuentes
#            ElapsedTime
# 889783 1 days 06:02:00
# 889680 1 days 01:00:00
# 693244 6 days 05:57:00
# 889778 8 days 05:59:00
# 889883 1 days 11:13:00
# ...                ...
# 713781 4 days 00:40:00
# 710142 5 days 17:20:00
# 631978 2 days 06:12:00
# 708233 5 days 06:02:00
# 708245 0 days 05:13:00
#
# [3372 rows x 1 columns]
#
# Average Elapsed Time for Felipe Fuentes : 4.0 days, 3.0 hours, 49.0 minutes, 56.0 seconds

# %%
#
# [60995 rows x 1 columns]
#
# Average Elapsed Time for Bob Blumenfield : 3.0 days, 5.0 hours, 54.0 minutes, 8.0 seconds
#
#
#
# Elapsed Times by City Council Members Mike Bonin
#              ElapsedTime
# 168893  59 days 18:17:00
# 708816   3 days 00:21:00
# 1204673  1 days 23:36:00
# 428038   1 days 16:57:00
# 301354   5 days 05:59:00
# ...                  ...
# 60194    4 days 03:39:00
# 341365   1 days 02:56:00
# 848261   7 days 00:45:00
# 521025   6 days 05:13:00
# 794705   1 days 21:18:00
#
# [56760 rows x 1 columns]
#
# Average Elapsed Time for Mike Bonin : 5.0 days, 21.0 hours, 40.0 minutes, 46.0 seconds
#
#
#
# Elapsed Times by City Council Members Paul Koretz
#             ElapsedTime
# 110792  3 days 01:24:00
# 310918  1 days 23:25:00
# 736258  5 days 23:57:00
# 1197355 0 days 17:27:00
# 298766  1 days 03:16:00
# ...                 ...
# 208580  1 days 19:24:00
# 292062  1 days 03:31:00
# 703100  1 days 20:27:00
# 525730  0 days 23:53:00
# 46165   3 days 00:26:00
#
# [53742 rows x 1 columns]
#
# Average Elapsed Time for Paul Koretz : 4.0 days, 12.0 hours, 57.0 minutes, 20.0 seconds
#
#
#
# Elapsed Times by City Council Members Paul Krekorian
#              ElapsedTime
# 1180921  7 days 01:28:00
# 156205   1 days 19:39:00
# 345260  34 days 05:08:00
# 39492    2 days 22:24:00
# 866162   1 days 03:01:00
# ...                  ...
# 893662   1 days 22:27:00
# 1150637  6 days 11:16:00
# 768750   1 days 01:44:00
# 893665   2 days 22:03:00
# 296740   1 days 07:36:00
#
# [74789 rows x 1 columns]
#
# Average Elapsed Time for Paul Krekorian : 5.0 days, 12.0 hours, 14.0 minutes, 54.0 seconds
#
#
#
# Elapsed Times by City Council Members Marqueece Harris-Dawson
#              ElapsedTime
# 1006081  0 days 18:54:00
# 638103  65 days 02:36:00
# 608895   4 days 18:41:00
# 1004110  1 days 00:45:00
# 615297   0 days 17:54:00
# ...                  ...
# 566881   0 days 19:37:00
# 268128   1 days 22:59:00
# 382702   2 days 18:50:00
# 1052234  4 days 19:20:00
# 568831   0 days 13:40:00
#
# [81821 rows x 1 columns]
#
# Average Elapsed Time for Marqueece Harris-Dawson : 4.0 days, 10.0 hours, 57.0 minutes, 6.0 seconds
#
#
#
# Elapsed Times by City Council Members Greig Smith
#              ElapsedTime
# 982965 244 days 20:53:00
#
# Average Elapsed Time for Greig Smith : 34.0 weeks, 6.0 days, 20.0 hours, 53.0 minutes

# %%
councilTime(r"C:\Users\hanaa\Downloads\MyLA311_Service_Request_Data_2019.csv")
# Out:
# C:\Users\hanaa\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3249: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# 1170842  1 days 21:49:00
# 1170562  1 days 09:06:00
# 1170987  0 days 19:21:00
#
# [70108 rows x 1 columns]
#
# Average Elapsed Time for Bob Blumenfield : 4.0 days, 16.0 hours, 46.0 minutes, 30.0 seconds
#
#
#
# Elapsed Times by City Council Members Marqueece Harris-Dawson
#              ElapsedTime
# 1010840  7 days 07:27:00
# 1240977  6 days 23:54:00
# 150585   5 days 19:02:00
# 262876   0 days 19:27:00
# 1282941  1 days 17:50:00
# ...                  ...
# 1180698 18 days 19:43:00
# 167925   0 days 08:17:00
# 915464   1 days 04:00:00
# 312594   1 days 16:08:00
# 1247895  0 days 00:01:00
#
# [84748 rows x 1 columns]
#
# Average Elapsed Time for Marqueece Harris-Dawson : 4.0 days, 13.0 hours, 37.0 minutes, 35.0 seconds
#
#
#
# Elapsed Times by City Council Members Herb J. Wesson Jr.
#            ElapsedTime
# 117824 1 days 01:30:00
# 736641 2 days 00:14:00
# 115112 1 days 21:44:00
# 117823 1 days 03:02:00
# 736791 1 days 15:29:00
# ...                ...
# 187360 1 days 00:46:00
# 464555 2 days 05:14:00
# 386369 0 days 22:19:00
# 464924 1 days 02:15:00
# 187648 1 days 02:54:00
#
# [86336 rows x 1 columns]
#
# Average Elapsed Time for Herb J. Wesson Jr. : 5.0 days, 5.0 hours, 15.0 minutes, 33.0 seconds
#
#
#
# Elapsed Times by City Council Members Curren D. Price Jr.
#               ElapsedTime
# 132999    0 days 19:43:00
# 653362    6 days 07:11:00
# 127002    0 days 22:56:00
# 667918  144 days 00:17:00
# 134950    0 days 10:08:00
# ...                   ...
# 737844    1 days 13:25:00
# 818291    0 days 17:51:00
# 1249192   1 days 02:11:00
# 1247104   6 days 01:33:00
# 1249299   0 days 23:45:00
#
# [72094 rows x 1 columns]
#
# Average Elapsed Time for Curren D. Price Jr. : 1.0 week, 4.0 days, 13.0 hours, 17.0 minutes, 32.0 seconds
#
#
#
# Elapsed Times by City Council Members Greig Smith
#            ElapsedTime
# 159288 3 days 23:54:00
# 525910 3 days 06:21:00
# 530115 7 days 08:49:00
# 519314 5 days 06:30:00
# 519404 6 days 07:51:00
# ...                ...
# 242332 4 days 03:33:00
# 266010 0 days 00:04:00
# 339282 0 days 21:45:00
# 196485 6 days 18:28:00
# 288524 4 days 22:11:00
#
# [49430 rows x 1 columns]
#
# Average Elapsed Time for Greig Smith : 3.0 days, 16.0 hours, 59.0 minutes, 53.0 seconds
#
#
#
# Elapsed Times by City Council Members John Lee
#             ElapsedTime
# 1280766 2 days 11:45:00
# 959050  6 days 11:13:00
# 936223  5 days 01:28:00
# 1033785 5 days 05:50:00
# 1124790 3 days 23:44:00
# ...                 ...
# 1199885 0 days 00:03:00
# 1265320 0 days 21:36:00
# 1255473 2 days 07:05:00
# 1103152 1 days 07:43:00
# 1181616 3 days 20:39:00
#
# [21524 rows x 1 columns]
#
# Average Elapsed Time for John Lee : 4.0 days, 1.0 hour, 36.0 minutes, 38.0 seconds
